# %% [markdown]
# # Data and Distributions

# %% [markdown]
# __Purpose:__ The purpose of this lecture is to cover topics of Statistics such as data types, distributions and graphing.
#
# __At the end of this lecture you will be able to:__
# > 1. Understand data types and distributions
# > 2. Graph data

# %%
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import math 
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1.1 Data and Distributions:

# %% [markdown]
# ### 1.1.1 Types of Data:

# %% [markdown]
# __Overview:__
# - In general, we can distinguish between two types of data:
# > 1. __[Qualitative Data](https://en.wikipedia.org/wiki/Qualitative_property):__ Qualitative Data contains discrete categories known as levels or categories. Qualitative Data can be further classified into four levels as described below
# > 2. __[Quantitative Data](https://en.wikipedia.org/wiki/Quantitative_research):__ Quantitative Data is also known as Numerical Data because it contains numbers as counts or measurements

# %% [markdown]
# ### 1.1.1.1 Qualitative Data:

# %% [markdown]
# __Overview:__
# - Qualitative Data can be further broken down into four categories:
# > 1. __[Nominal](https://en.wikipedia.org/wiki/Level_of_measurement#Nominal_level):__ Nominal (Categorical) data includes levels that can be differentiated only based on the names of the categories and not on an implicit ordering
# >> - Nominal data can be operated using $=$ and $\neq$ and can be grouped into categories
# >> - For example, Nominal Data includes Gender, States of the United States of America, Eye Color, Marital Status, etc.
# >> - We CAN'T say one level is less than or greater than another
# > 2. __[Ordinal](https://en.wikipedia.org/wiki/Level_of_measurement#Ordinal_scale):__ Ordinal data includes levels that can be differentiated based on an implicit ordering, but the distances between the levels is unknown
# >> - Ordinal data can be operated using $>$ and $<$ and can be sorted
# >> - For example, Likert Scale (Like, Like Somewhat, Neutral, Dislike Somewhat, Dislike)
# >> - We CAN'T say level 1 is less than level 2 by a difference of 1
# > 3. __[Interval](https://en.wikipedia.org/wiki/Level_of_measurement#Interval_scale):__ Interval data includes levels that can be differentiated based on an implicit ordering AND the distances between the levels is known, but the ratio between levels is unknown
# >> - Interval data can be operated using $+$ and $-$ and can be measured using a yardstick method
# >> - For example, Interval data includes temperature on the Celsius Scale, Date when measured from a specific start point, and location in Cartesian coordinates
# >> - We CAN'T say level 1 is twice as large as level 2
# > 4. __[Ratio](https://en.wikipedia.org/wiki/Level_of_measurement#Ratio_scale):__ Ratio data includes levels that can be differentiated based on an implicit ordering AND the distances between the level is known AND the ratio between the levels is known because there is a unique and non-arbitrary zero value
# >> - Ratio data can be operated using $*$ and $/$ and can be measured using a ratio operation
# >> - For example, Ratio data includes temperature on the Kelvin Scale and most measurements in Physics (mass, energy, etc.)

# %% [markdown]
# ### Problem 1:
#
# Give an example of each type of qualitative data above (other than the examples that are mentioned in the definition)

# %%
# write your answer here

# %% [markdown]
# ### 1.1.1.2 Quantitative Data:

# %% [markdown]
# __Overview:__
# - Quantitative Data can be further broken into two categories:
# > 1. __[Discrete Data](https://en.wikipedia.org/wiki/Continuous_or_discrete_variable#Discrete_variable):__ Discrete data can only take particular values over a range
# >> - For example, number of three point shots attempted, made, and missed
# > 2. __[Continuous Data](https://en.wikipedia.org/wiki/Continuous_or_discrete_variable#Continuous_variable):__ Continuous data are not restricted to defined values over a range, but instead can take on any value over a range
# >> - For example, height and weight
#
# __Helpful Points:__
# 1. Technically, Categorical Data mentioned above is also an example of Discrete Data
# 2. It is possible to group Continuous Data into distinct, discrete categories known as bins (i.e. 100 - 120 cm, 121 - 130 cm, 131 - 150 cm, > 150 cm, etc.)

# %% [markdown]
# ### 1.2.2 Graphing Data:

# %% [markdown]
# __Overview:__
# - Depending on the type of data there exists different types of graphs that we can use to explore the properties of the data
# > 1. __Qualitative Data:__ Qualitative Data can be summarized using the following methods:
# >> a. Pie Charts <br>
# >> b. Bar Charts
# > 2. __Quantitative Data:__ Quantitative Data can be summarized using the following methods:
# >> a. Histograms <br>
# >> b. Scatter Plots <br>
# >> c. Line Graph
#
# __Helpful Points:__
# 1. There is lots of debate and best practices shared regarding the type of graph that should be chosen. Feel free to read about this online, but [here](https://blog.hubspot.com/marketing/types-of-graphs-for-data-visualization) is one such resource
#
# __Practice:__ Examples of Graphing Data in Python

# %% [markdown]
# The NBA data willl be used here to perform Statistical Analysis.

# %%
# read in data to analyze 
nba_df = pd.read_csv("NBA_GameLog_2010_2017.csv")

# %%
# view the data 
nba_df.head(10)
# Out:
#         GameType  Season Team   G      Date  Home  Opp W.L  Tm.Pts  Opp.Pts  \
# 0  RegularSeason    2010  ATL   1  10/28/09     1  IND   W     120      109
# 1  RegularSeason    2010  ATL   2  10/30/09     1  WAS   W     100       89
# 2  RegularSeason    2010  ATL   3   11/1/09     0  LAL   L     110      118
# 3  RegularSeason    2010  ATL   4   11/3/09     0  POR   W      97       91
# 4  RegularSeason    2010  ATL   5   11/4/09     0  SAC   W     113      105
# 5  RegularSeason    2010  ATL   6   11/6/09     0  CHA   L      83      103
# 6  RegularSeason    2010  ATL   7   11/7/09     1  DEN   W     125      100
# 7  RegularSeason    2010  ATL   8  11/11/09     0  NYK   W     114      101
# 8  RegularSeason    2010  ATL   9  11/13/09     0  BOS   W      97       86
# 9  RegularSeason    2010  ATL  10  11/14/09     1  NOH   W     121       98
#
#    ...  Tm.AST  Tm.STL  Tm.BLK  Tm.TOV  Tm.PF  Home.Attendance  \
# 0  ...      30      16       6      10     25          17998.0
# 1  ...      18       5       7      12     24          17079.0
# 2  ...      21       8       3      19     21          18997.0
# 3  ...      21       4       7      11     15          20325.0
# 4  ...      17       2      10      16     20          11751.0
# 5  ...      10       7      11       7     20          15874.0
# 6  ...      30       4       9       8     33          17801.0
# 7  ...      23       7       3      15     19          19699.0
# 8  ...      19       7       6      13     20          18624.0
# 9  ...      27      10       3      14     19          18572.0
#
#           Referee1          Referee2           Referee3  Referee4
# 0    Mike Callahan     Olandis Poole         Zach Zarba       NaN
# 1       Kevin Fehr  Derrick Stafford     Gary Zielinski       NaN
# 2     James Capers       Bob Delaney       Mark Lindsay       NaN
# 3      Matt Boland     Violet Palmer  Bennett Salvatore       NaN
# 4    Tony Brothers     Phil Robinson      Eddie F. Rush       NaN
# 5       Eric Dalen     Ron Garretson      Michael Smith       NaN
# 6      Mark Ayotte        Eric Lewis    Monty McCutchen       NaN
# 7     James Capers      Joe Crawford       Mark Lindsay       NaN
# 8  Derrick Collins   Monty McCutchen      Olandis Poole       NaN
# 9     Bennie Adams     Phil Robinson      Eddie F. Rush       NaN
#
# [10 rows x 31 columns]

# %%
# convert to datetime
nba_df['Date'] = pd.to_datetime(nba_df['Date'])

# %%
# make index the datetime column for easier indexing
nba_df.set_index("Date", inplace = True)

# %%
nba_df.head(5)
# Out:
#                  GameType  Season Team  G  Home  Opp W.L  Tm.Pts  Opp.Pts  \
# Date
# 2009-10-28  RegularSeason    2010  ATL  1     1  IND   W     120      109
# 2009-10-30  RegularSeason    2010  ATL  2     1  WAS   W     100       89
# 2009-11-01  RegularSeason    2010  ATL  3     0  LAL   L     110      118
# 2009-11-03  RegularSeason    2010  ATL  4     0  POR   W      97       91
# 2009-11-04  RegularSeason    2010  ATL  5     0  SAC   W     113      105
#
#             Tm.FGM  ...  Tm.AST  Tm.STL  Tm.BLK  Tm.TOV  Tm.PF  \
# Date                ...
# 2009-10-28      46  ...      30      16       6      10     25
# 2009-10-30      32  ...      18       5       7      12     24
# 2009-11-01      40  ...      21       8       3      19     21
# 2009-11-03      37  ...      21       4       7      11     15
# 2009-11-04      46  ...      17       2      10      16     20
#
#             Home.Attendance       Referee1          Referee2  \
# Date
# 2009-10-28          17998.0  Mike Callahan     Olandis Poole
# 2009-10-30          17079.0     Kevin Fehr  Derrick Stafford
# 2009-11-01          18997.0   James Capers       Bob Delaney
# 2009-11-03          20325.0    Matt Boland     Violet Palmer
# 2009-11-04          11751.0  Tony Brothers     Phil Robinson
#
#                      Referee3  Referee4
# Date
# 2009-10-28         Zach Zarba       NaN
# 2009-10-30     Gary Zielinski       NaN
# 2009-11-01       Mark Lindsay       NaN
# 2009-11-03  Bennett Salvatore       NaN
# 2009-11-04      Eddie F. Rush       NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Example 1 (Graphing Qualitative Data):

# %% [markdown]
# First, we have to determine which columns in the NBA data set are qualitative variables:

# %%
nba_df.dtypes
# Out:
# GameType            object
# Season               int64
# Team                object
# G                    int64
# Home                 int64
# Opp                 object
# W.L                 object
# Tm.Pts               int64
# Opp.Pts              int64
# Tm.FGM               int64
# Tm.FGA               int64
# Tm.FG_Perc         float64
# Tm.3PM               int64
# Tm.3PA               int64
# Tm.3P_Perc         float64
# Tm.FTM               int64
# Tm.FTA               int64
# Tm.FT_Perc         float64
# Tm.ORB               int64
# Tm.TRB               int64
# Tm.AST               int64
# Tm.STL               int64
# Tm.BLK               int64
# Tm.TOV               int64
# Tm.PF                int64
# Home.Attendance    float64
# Referee1            object
# Referee2            object
# Referee3            object
# Referee4            object
# dtype: object

# %% [markdown]
# We can see that the GameType, Team, Opp, W.L and Referee columns refer to qualitative data

# %% [markdown]
# ### Example 1.1 (Frequency Table):

# %%
tor_2016_2017 = nba_df.loc[(nba_df.loc[:, "Season"] == 2017) & (nba_df.loc[:, "Team"] == "TOR"),]
# tor_2016_2017 = nba_df.loc[(nba_df.loc[:, "Season"] == 2017) & (nba_df.loc[:, "Team"] == "TOR")]['GameType']
print(nba_df.loc[nba_df.loc[:, "Season"] == 2017])
tor_2016_2017
# Out:
#                  GameType  Season Team   G  Home  Opp W.L  Tm.Pts  Opp.Pts  \
# Date
# 2016-10-27  RegularSeason    2017  ATL   1     1  WAS   W     114       99
# 2016-10-29  RegularSeason    2017  ATL   2     0  PHI   W     104       72
# 2016-10-31  RegularSeason    2017  ATL   3     1  SAC   W     106       95
# 2016-11-02  RegularSeason    2017  ATL   4     1  LAL   L     116      123
# 2016-11-04  RegularSeason    2017  ATL   5     0  WAS   L      92       95
# ...                   ...     ...  ...  ..   ...  ...  ..     ...      ...
# 2017-05-04       Playoffs    2017  WAS   9     1  BOS   W     116       89
# 2017-05-07       Playoffs    2017  WAS  10     1  BOS   W     121      102
# 2017-05-10       Playoffs    2017  WAS  11     0  BOS   L     101      123
# 2017-05-12       Playoffs    2017  WAS  12     1  BOS   W      92       91
# 2017-05-15       Playoffs    2017  WAS  13     0  BOS   L     105      115
#
#             Tm.FGM  ...  Tm.AST  Tm.STL  Tm.BLK  Tm.TOV  Tm.PF  \
# Date                ...
# 2016-10-27      44  ...      28      13       7      21     19
# 2016-10-29      42  ...      31      11       7      12     14
# 2016-10-31      33  ...      24      11       6      13     20
# 2016-11-02      41  ...      30      10       1      18     19
# 2016-11-04      32  ...      22      12       3      18     24
# ...            ...  ...     ...     ...     ...     ...    ...
# 2017-05-04      43  ...      26       7       5       9     26
# 2017-05-07      44  ...      29      13       3      19     22
# 2017-05-10      35  ...      21       5       5      12     18
# 2017-05-12      37  ...      20       4       7      12     24
# 2017-05-15      36  ...      18       6       4      15     17
#
#             Home.Attendance         Referee1           Referee2  \
# Date
# 2016-10-27          19049.0     Bennie Adams    Monty McCutchen
# 2016-10-29          16312.0     Kevin Cutler  Courtney Kirkland
# 2016-10-31          12501.0      Mark Ayotte          Karl Lane
# 2016-11-02          13800.0       John Goble           J.T. Orr
# 2016-11-04          14663.0     Scott Foster        Marat Kogut
# ...                     ...              ...                ...
# 2017-05-04          20356.0       Tony Brown       James Capers
# 2017-05-07          20356.0      Sean Corbin       Dan Crawford
# 2017-05-10          18624.0    Mike Callahan          Ed Malloy
# 2017-05-12          20356.0    Tony Brothers         John Goble
# 2017-05-15          18624.0  Monty McCutchen   Derrick Stafford
#
#                     Referee3  Referee4
# Date
# 2016-10-27       Aaron Smith       NaN
# 2016-10-29  Derrick Stafford       NaN
# 2016-10-31       Rodney Mott       NaN
# 2016-11-02    Jason Phillips       NaN
# 2016-11-04    Gary Zielinski       NaN
# ...                      ...       ...
# 2017-05-04   Monty McCutchen       NaN
# 2017-05-07     Ron Garretson       NaN
# 2017-05-10       Sean Wright       NaN
# 2017-05-12         Ken Mauer       NaN
# 2017-05-15        Zach Zarba       NaN
#
# [2596 rows x 30 columns]
#                  GameType  Season Team   G  Home  Opp W.L  Tm.Pts  Opp.Pts  \
# Date
# 2016-10-26  RegularSeason    2017  TOR   1     1  DET   W     109       91
# 2016-10-28  RegularSeason    2017  TOR   2     1  CLE   L      91       94
# 2016-10-31  RegularSeason    2017  TOR   3     1  DEN   W     105      102
# 2016-11-02  RegularSeason    2017  TOR   4     0  WAS   W     113      103
# 2016-11-04  RegularSeason    2017  TOR   5     1  MIA   W      96       87
# ...                   ...     ...  ...  ..   ...  ...  ..     ...      ...
# 2017-04-27       Playoffs    2017  TOR   6     0  MIL   W      92       89
# 2017-05-01       Playoffs    2017  TOR   7     0  CLE   L     105      116
# 2017-05-03       Playoffs    2017  TOR   8     0  CLE   L     103      125
# 2017-05-05       Playoffs    2017  TOR   9     1  CLE   L      94      115
# 2017-05-07       Playoffs    2017  TOR  10     1  CLE   L     102      109
#
#             Tm.FGM  ...  Tm.AST  Tm.STL  Tm.BLK  Tm.TOV  Tm.PF  \
# Date                ...
# 2016-10-26      41  ...      17       8       0      11     22
# 2016-10-28      35  ...      12       9       3      18     20
# 2016-10-31      41  ...      16       7       9       7     28
# 2016-11-02      43  ...      21      16       2      13     24
# 2016-11-04      37  ...      14       7       5      15     16
# ...            ...  ...     ...     ...     ...     ...    ...
# 2017-04-27      32  ...      14       9       4      14     20
# 2017-05-01      39  ...      22       5       5      12     22
# 2017-05-03      42  ...      21       8       4      13     21
# 2017-05-05      38  ...      17       9       4       4     21
# 2017-05-07      40  ...      28       7       3      11     18
#
#             Home.Attendance         Referee1         Referee2  \
# Date
# 2016-10-26          19800.0      Mark Ayotte     James Capers
# 2016-10-28          19800.0        Ken Mauer    Michael Smith
# 2016-10-31          19800.0  Monty McCutchen      Aaron Smith
# 2016-11-02          19581.0      Matt Boland  Lauren Holtkamp
# 2016-11-04          19800.0     Curtis Blair     Bill Kennedy
# ...                     ...              ...              ...
# 2017-04-27          18717.0    Tony Brothers       Marc Davis
# 2017-05-01          20562.0       Eric Lewis  Monty McCutchen
# 2017-05-03          20562.0      Sean Corbin     Dan Crawford
# 2017-05-05          20384.0    Mike Callahan  Kane Fitzgerald
# 2017-05-07          20307.0    Tony Brothers     Scott Foster
#
#                     Referee3  Referee4
# Date
# 2016-10-26   Derrick Collins       NaN
# 2016-10-28        Josh Tiven       NaN
# 2016-10-31    Gary Zielinski       NaN
# 2016-11-02  Derrick Stafford       NaN
# 2016-11-04        Eric Lewis       NaN
# ...                      ...       ...
# 2017-04-27       Rodney Mott       NaN
# 2017-05-01  Derrick Stafford       NaN
# 2017-05-03       Sean Wright       NaN
# 2017-05-05      Bill Kennedy       NaN
# 2017-05-07        Pat Fraher       NaN
#
# [92 rows x 30 columns]

# %%
tor_2016_2017.columns
# Out:
# Index(['GameType', 'Season', 'Team', 'G', 'Home', 'Opp', 'W.L', 'Tm.Pts',
#        'Opp.Pts', 'Tm.FGM', 'Tm.FGA', 'Tm.FG_Perc', 'Tm.3PM', 'Tm.3PA',
#        'Tm.3P_Perc', 'Tm.FTM', 'Tm.FTA', 'Tm.FT_Perc', 'Tm.ORB', 'Tm.TRB',
#        'Tm.AST', 'Tm.STL', 'Tm.BLK', 'Tm.TOV', 'Tm.PF', 'Home.Attendance',
#        'Referee1', 'Referee2', 'Referee3', 'Referee4'],
#       dtype='object')

# %%
tor_2016_2017
# Out:
#                  GameType  Season Team   G  Home  Opp W.L  Tm.Pts  Opp.Pts  \
# Date
# 2016-10-26  RegularSeason    2017  TOR   1     1  DET   W     109       91
# 2016-10-28  RegularSeason    2017  TOR   2     1  CLE   L      91       94
# 2016-10-31  RegularSeason    2017  TOR   3     1  DEN   W     105      102
# 2016-11-02  RegularSeason    2017  TOR   4     0  WAS   W     113      103
# 2016-11-04  RegularSeason    2017  TOR   5     1  MIA   W      96       87
# ...                   ...     ...  ...  ..   ...  ...  ..     ...      ...
# 2017-04-27       Playoffs    2017  TOR   6     0  MIL   W      92       89
# 2017-05-01       Playoffs    2017  TOR   7     0  CLE   L     105      116
# 2017-05-03       Playoffs    2017  TOR   8     0  CLE   L     103      125
# 2017-05-05       Playoffs    2017  TOR   9     1  CLE   L      94      115
# 2017-05-07       Playoffs    2017  TOR  10     1  CLE   L     102      109
#
#             Tm.FGM  ...  Tm.AST  Tm.STL  Tm.BLK  Tm.TOV  Tm.PF  \
# Date                ...
# 2016-10-26      41  ...      17       8       0      11     22
# 2016-10-28      35  ...      12       9       3      18     20
# 2016-10-31      41  ...      16       7       9       7     28
# 2016-11-02      43  ...      21      16       2      13     24
# 2016-11-04      37  ...      14       7       5      15     16
# ...            ...  ...     ...     ...     ...     ...    ...
# 2017-04-27      32  ...      14       9       4      14     20
# 2017-05-01      39  ...      22       5       5      12     22
# 2017-05-03      42  ...      21       8       4      13     21
# 2017-05-05      38  ...      17       9       4       4     21
# 2017-05-07      40  ...      28       7       3      11     18
#
#             Home.Attendance         Referee1         Referee2  \
# Date
# 2016-10-26          19800.0      Mark Ayotte     James Capers
# 2016-10-28          19800.0        Ken Mauer    Michael Smith
# 2016-10-31          19800.0  Monty McCutchen      Aaron Smith
# 2016-11-02          19581.0      Matt Boland  Lauren Holtkamp
# 2016-11-04          19800.0     Curtis Blair     Bill Kennedy
# ...                     ...              ...              ...
# 2017-04-27          18717.0    Tony Brothers       Marc Davis
# 2017-05-01          20562.0       Eric Lewis  Monty McCutchen
# 2017-05-03          20562.0      Sean Corbin     Dan Crawford
# 2017-05-05          20384.0    Mike Callahan  Kane Fitzgerald
# 2017-05-07          20307.0    Tony Brothers     Scott Foster
#
#                     Referee3  Referee4
# Date
# 2016-10-26   Derrick Collins       NaN
# 2016-10-28        Josh Tiven       NaN
# 2016-10-31    Gary Zielinski       NaN
# 2016-11-02  Derrick Stafford       NaN
# 2016-11-04        Eric Lewis       NaN
# ...                      ...       ...
# 2017-04-27       Rodney Mott       NaN
# 2017-05-01  Derrick Stafford       NaN
# 2017-05-03       Sean Wright       NaN
# 2017-05-05      Bill Kennedy       NaN
# 2017-05-07        Pat Fraher       NaN
#
# [92 rows x 30 columns]

# %%
freq_table = pd.DataFrame(tor_2016_2017.loc[:, "W.L"].value_counts())
freq_table.columns = ["Frequency"]
# freq_table

# %%
freq_table["RelativeFrequency"] = freq_table["Frequency"] / freq_table.Frequency.sum()
freq_table
# Out:
#    Frequency  RelativeFrequency
# W         55           0.597826
# L         37           0.402174

# %% [markdown]
# ### Example 1.2 (Pie Charts):

# %%
plt.figure(figsize = [5,5])
plt.pie(freq_table.RelativeFrequency, labels=["W", "L"]);

# %% [markdown]
# ### Example 1.3 (Bar Charts):

# %%
plt.bar(freq_table.index,freq_table.RelativeFrequency);

# %% [markdown]
# ### Example 2 (Graphing Quantitative Data):

# %% [markdown]
# ### Example 2.1 (Histogram):

# %%
# histogram of the team's points
plt.hist(tor_2016_2017.loc[:, "Tm.Pts"])
# Out:
# (array([ 3.,  3.,  9., 11., 16., 12., 16., 10.,  9.,  3.]),
#  array([ 77. ,  82.5,  88. ,  93.5,  99. , 104.5, 110. , 115.5, 121. ,
#         126.5, 132. ]),
#  <BarContainer object of 10 artists>)

# %%
# histogram of the team's FG Percentage
plt.hist(tor_2016_2017.loc[:, "Tm.FG_Perc"])
# Out:
# (array([ 5.,  5., 10.,  8., 17., 17., 10., 10.,  7.,  3.]),
#  array([0.337 , 0.3623, 0.3876, 0.4129, 0.4382, 0.4635, 0.4888, 0.5141,
#         0.5394, 0.5647, 0.59  ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(tor_2016_2017.loc[:, "Tm.FG_Perc"],kde=False); # same as above but using seaborn

# %% [markdown]
# The two histograms above may not look the same because the "binning" process which allocates the data into a pre-defined number of bins may be different, affecting the final visual of the histogram.

# %% [markdown]
# In the histograms shown above,
#
# > 1. __X-Axis__: The X-Axis represnts the range of values that the Team Field Goal Percentage takes on
# > 2. __Y-Axis__: The Y-Axis represents the frequency count of the number of observations (games) that fall into each bin

# %%
# cumulative frequency histogram 
sns.distplot(tor_2016_2017.loc[:, "Tm.FG_Perc"], hist_kws={"cumulative":True},kde_kws={"cumulative":True})
# Out:
# <AxesSubplot:xlabel='Tm.FG_Perc', ylabel='Density'>

# %% [markdown]
# In the cumulative frequency histogram shown above,
#
# > 1. __X-Axis__: The X-Axis represents the range of values that the Team Field Goal Percentage takes on
# > 2. __Y-Axis__: The Y-Axis represents the cumulative frequency count of the number of observations (games) that fall into each bin. We can interpret this in the following way:
# >> - In 20% of the games, the team had a Field Goal Percentage of 0.40 or less
# >> - In about 50% of the games, the team had a Field Goal Percentage of 0.45 or less
# >> - In about 80% of the games, the team had a Field Goal Percentage of 0.50 or less

# %% [markdown]
# ### Example 2.2 (Scatter Plots):

# %%
tor_2016_2017_home = tor_2016_2017.loc[(tor_2016_2017.loc[:, "Home"] == 1), ]
tor_2016_2017_home
# Out:
#                  GameType  Season Team   G  Home  Opp W.L  Tm.Pts  Opp.Pts  \
# Date
# 2016-10-26  RegularSeason    2017  TOR   1     1  DET   W     109       91
# 2016-10-28  RegularSeason    2017  TOR   2     1  CLE   L      91       94
# 2016-10-31  RegularSeason    2017  TOR   3     1  DEN   W     105      102
# 2016-11-04  RegularSeason    2017  TOR   5     1  MIA   W      96       87
# 2016-11-06  RegularSeason    2017  TOR   6     1  SAC   L      91       96
# 2016-11-12  RegularSeason    2017  TOR   9     1  NYK   W     118      107
# 2016-11-16  RegularSeason    2017  TOR  11     1  GSW   L     121      127
# 2016-11-28  RegularSeason    2017  TOR  17     1  PHI   W     122       95
# 2016-11-30  RegularSeason    2017  TOR  18     1  MEM   W     120      105
# 2016-12-02  RegularSeason    2017  TOR  19     1  LAL   W     113       80
# 2016-12-03  RegularSeason    2017  TOR  20     1  ATL   W     128       84
# 2016-12-05  RegularSeason    2017  TOR  21     1  CLE   L     112      116
# 2016-12-08  RegularSeason    2017  TOR  22     1  MIN   W     124      110
# 2016-12-12  RegularSeason    2017  TOR  24     1  MIL   W     122      100
# 2016-12-16  RegularSeason    2017  TOR  26     1  ATL   L     121      125
# 2016-12-20  RegularSeason    2017  TOR  28     1  BRK   W     116      104
# 2017-01-05  RegularSeason    2017  TOR  35     1  UTA   W     101       93
# 2017-01-08  RegularSeason    2017  TOR  37     1  HOU   L     122      129
# 2017-01-10  RegularSeason    2017  TOR  38     1  BOS   W     114      106
# 2017-01-13  RegularSeason    2017  TOR  39     1  BRK   W     132      113
# 2017-01-15  RegularSeason    2017  TOR  40     1  NYK   W     116      101
# 2017-01-22  RegularSeason    2017  TOR  44     1  PHO   L     103      115
# 2017-01-24  RegularSeason    2017  TOR  45     1  SAS   L     106      108
# 2017-01-27  RegularSeason    2017  TOR  47     1  MIL   W     102       86
# 2017-01-29  RegularSeason    2017  TOR  48     1  ORL   L     113      114
# 2017-01-31  RegularSeason    2017  TOR  49     1  NOP   W     108      106
# 2017-02-06  RegularSeason    2017  TOR  53     1  LAC   W     118      109
# 2017-02-12  RegularSeason    2017  TOR  55     1  DET   L     101      102
# 2017-02-15  RegularSeason    2017  TOR  57     1  CHO   W      90       85
# 2017-02-24  RegularSeason    2017  TOR  58     1  BOS   W     107       97
# 2017-02-26  RegularSeason    2017  TOR  59     1  POR   W     112      106
# 2017-03-01  RegularSeason    2017  TOR  61     1  WAS   L      96      105
# 2017-03-13  RegularSeason    2017  TOR  67     1  DAL   W     100       78
# 2017-03-16  RegularSeason    2017  TOR  68     1  OKC   L     102      123
# 2017-03-19  RegularSeason    2017  TOR  70     1  IND   W     116       91
# 2017-03-21  RegularSeason    2017  TOR  71     1  CHI   W     122      120
# 2017-03-27  RegularSeason    2017  TOR  74     1  ORL   W     131      112
# 2017-03-29  RegularSeason    2017  TOR  75     1  CHO   L     106      110
# 2017-03-31  RegularSeason    2017  TOR  76     1  IND   W     111      100
# 2017-04-02  RegularSeason    2017  TOR  77     1  PHI   W     113      105
# 2017-04-07  RegularSeason    2017  TOR  80     1  MIA   W      96       94
# 2017-04-15       Playoffs    2017  TOR   1     1  MIL   L      83       97
# 2017-04-18       Playoffs    2017  TOR   2     1  MIL   W     106      100
# 2017-04-24       Playoffs    2017  TOR   5     1  MIL   W     118       93
# 2017-05-05       Playoffs    2017  TOR   9     1  CLE   L      94      115
# 2017-05-07       Playoffs    2017  TOR  10     1  CLE   L     102      109
#
#             Tm.FGM  ...  Tm.AST  Tm.STL  Tm.BLK  Tm.TOV  Tm.PF  \
# Date                ...
# 2016-10-26      41  ...      17       8       0      11     22
# 2016-10-28      35  ...      12       9       3      18     20
# 2016-10-31      41  ...      16       7       9       7     28
# 2016-11-04      37  ...      14       7       5      15     16
# 2016-11-06      30  ...      22       6       5       6     26
# 2016-11-12      39  ...      18      10       6      11     20
# 2016-11-16      37  ...      16       8       1      14     22
# 2016-11-28      42  ...      22      11       8      12     14
# 2016-11-30      38  ...      23       8       3      18     25
# 2016-12-02      45  ...      25       8       5      10     18
# 2016-12-03      53  ...      28      14       7      12     17
# 2016-12-05      38  ...      22       8       5       7     22
# 2016-12-08      43  ...      25       5       5       8     19
# 2016-12-12      42  ...      26       7       2      14     18
# 2016-12-16      47  ...      20       7       5       9     27
# 2016-12-20      42  ...      19      13       9      13     21
# 2017-01-05      36  ...      14      10       6       4     19
# 2017-01-08      42  ...      19       7       3      17     25
# 2017-01-10      41  ...      17       9       7      17     21
# 2017-01-13      52  ...      21       7       9       8     17
# 2017-01-15      44  ...      21       9       4      10     20
# 2017-01-22      33  ...      19       9       8       9     20
# 2017-01-24      38  ...      10       9       8      13     25
# 2017-01-27      37  ...      20       9      11      14     19
# 2017-01-29      36  ...      19       8       3      11     20
# 2017-01-31      43  ...      19       5       6      14     19
# 2017-02-06      41  ...      20       6       1       9     23
# 2017-02-12      38  ...      18       4       5       9     18
# 2017-02-15      32  ...      19       8       4      14     13
# 2017-02-24      40  ...      15       7       4       9     21
# 2017-02-26      42  ...      16       7       5      10     24
# 2017-03-01      33  ...      11       8       4      11     18
# 2017-03-13      37  ...      19       7       6      12     16
# 2017-03-16      37  ...      15      10      10      14     20
# 2017-03-19      45  ...      25       7       7      16     20
# 2017-03-21      47  ...      18       6       4      16     23
# 2017-03-27      49  ...      24       7       8      15     25
# 2017-03-29      38  ...      23       4       7      13     22
# 2017-03-31      37  ...      23       7       5      14     23
# 2017-04-02      46  ...      25      12       9      15     19
# 2017-04-07      35  ...      14      10       4      15     24
# 2017-04-15      27  ...      15       3       4      10     21
# 2017-04-18      37  ...      24       6       4      12     22
# 2017-04-24      41  ...      28      10       6      17     24
# 2017-05-05      38  ...      17       9       4       4     21
# 2017-05-07      40  ...      28       7       3      11     18
#
#             Home.Attendance          Referee1           Referee2  \
# Date
# 2016-10-26          19800.0       Mark Ayotte       James Capers
# 2016-10-28          19800.0         Ken Mauer      Michael Smith
# 2016-10-31          19800.0   Monty McCutchen        Aaron Smith
# 2016-11-04          19800.0      Curtis Blair       Bill Kennedy
# 2016-11-06          19800.0       Kevin Scott         Scott Wall
# 2016-11-12          19800.0       Matt Boland       Scott Foster
# 2016-11-16          21050.0     Ron Garretson        Marat Kogut
# 2016-11-28          19800.0      Curtis Blair   Leroy Richardson
# 2016-11-30          19800.0        Tyler Ford      Michael Smith
# 2016-12-02          19800.0       Mark Ayotte        Sean Corbin
# 2016-12-03          19800.0      Nick Buchert        Aaron Smith
# 2016-12-05          19800.0      James Capers         Eric Dalen
# 2016-12-08          19800.0      Scott Foster        Marat Kogut
# 2016-12-12          19800.0   Kane Fitzgerald  Courtney Kirkland
# 2016-12-16          19800.0         Ed Malloy    C.J. Washington
# 2016-12-20          19800.0        Tony Brown         Tyler Ford
# 2017-01-05          19800.0   Kane Fitzgerald        Aaron Smith
# 2017-01-08          19800.0     Brent Barnaky        Sean Corbin
# 2017-01-10          19800.0      Kevin Cutler         Josh Tiven
# 2017-01-13          19800.0     Mike Callahan        Kevin Scott
# 2017-01-15          19800.0         Ken Mauer      Michael Smith
# 2017-01-22          19800.0        Marc Davis         Eric Lewis
# 2017-01-24          19800.0      Dan Crawford         Pat Fraher
# 2017-01-27          19800.0        Tony Brown       James Capers
# 2017-01-29          19800.0       Matt Boland        Brian Forte
# 2017-01-31          19800.0     Mike Callahan    Derrick Collins
# 2017-02-06          19800.0   Kane Fitzgerald         Tre Maddox
# 2017-02-12          19800.0  Derek Richardson   Leroy Richardson
# 2017-02-15          19800.0       Sean Corbin         Tyler Ford
# 2017-02-24          19800.0   Kane Fitzgerald        Jacyn Goble
# 2017-02-26          19800.0       Mark Ayotte         Tony Brown
# 2017-03-01          19800.0     Tony Brothers  Courtney Kirkland
# 2017-03-13          19800.0    Steve Anderson      Mike Callahan
# 2017-03-16          19800.0        Marc Davis     Mitchell Ervin
# 2017-03-19          19800.0     Tony Brothers         Tony Brown
# 2017-03-21          19800.0        Tre Maddox          Ken Mauer
# 2017-03-27          19800.0      Bill Kennedy           J.T. Orr
# 2017-03-29          19800.0   Derrick Collins    Kane Fitzgerald
# 2017-03-31          19800.0     David Guthrie    Monty McCutchen
# 2017-04-02          19800.0      Nick Buchert        Marat Kogut
# 2017-04-07          19800.0     Mike Callahan       Mark Lindsay
# 2017-04-15          20133.0        John Goble          Ed Malloy
# 2017-04-18          20077.0     Mike Callahan       Bill Kennedy
# 2017-04-24          20251.0      James Capers         Pat Fraher
# 2017-05-05          20384.0     Mike Callahan    Kane Fitzgerald
# 2017-05-07          20307.0     Tony Brothers       Scott Foster
#
#                        Referee3  Referee4
# Date
# 2016-10-26      Derrick Collins       NaN
# 2016-10-28           Josh Tiven       NaN
# 2016-10-31       Gary Zielinski       NaN
# 2016-11-04           Eric Lewis       NaN
# 2016-11-06          Sean Wright       NaN
# 2016-11-12          Jacyn Goble       NaN
# 2016-11-16            Ed Malloy       NaN
# 2016-11-28       James Williams       NaN
# 2016-11-30          Sean Wright       NaN
# 2016-12-02     Derek Richardson       NaN
# 2016-12-03       Tom Washington       NaN
# 2016-12-05             J.T. Orr       NaN
# 2016-12-08         Mark Lindsay       NaN
# 2016-12-12          Kevin Scott       NaN
# 2016-12-16       James Williams       NaN
# 2016-12-20          Sean Wright       NaN
# 2017-01-05       Tom Washington       NaN
# 2017-01-08     Haywoode Workman       NaN
# 2017-01-10          Sean Wright       NaN
# 2017-01-13            Leon Wood       NaN
# 2017-01-15           Scott Wall       NaN
# 2017-01-22  Gediminas Petraitis       NaN
# 2017-01-24           Ben Taylor       NaN
# 2017-01-27     Derek Richardson       NaN
# 2017-01-29        Dedric Taylor       NaN
# 2017-01-31           Eric Dalen       NaN
# 2017-02-06          Sean Wright       NaN
# 2017-02-12          Sean Wright       NaN
# 2017-02-15           Josh Tiven       NaN
# 2017-02-24         Bill Spooner       NaN
# 2017-02-26            Ken Mauer       NaN
# 2017-03-01     Derek Richardson       NaN
# 2017-03-13       Gary Zielinski       NaN
# 2017-03-16           Josh Tiven       NaN
# 2017-03-19            Leon Wood       NaN
# 2017-03-21       James Williams       NaN
# 2017-03-27           Scott Wall       NaN
# 2017-03-29           Tyler Ford       NaN
# 2017-03-31  Gediminas Petraitis       NaN
# 2017-04-02         Bill Spooner       NaN
# 2017-04-07        Dedric Taylor       NaN
# 2017-04-15            Ken Mauer       NaN
# 2017-04-18         Mark Lindsay       NaN
# 2017-04-24    Courtney Kirkland       NaN
# 2017-05-05         Bill Kennedy       NaN
# 2017-05-07           Pat Fraher       NaN
#
# [46 rows x 30 columns]

# %%
# scatter plot of the home attendance 
plt.scatter(tor_2016_2017_home.index, tor_2016_2017_home.loc[:, "Home.Attendance"]);

# %%
# scatter plot of the turnovers 
plt.scatter(tor_2016_2017.index, tor_2016_2017.loc[:, "Tm.TOV"])

# %%
# combine scatter plot and histogram of the turnovers 
sns.jointplot(tor_2016_2017.loc[:, "G"], tor_2016_2017.loc[:, "Tm.TOV"])

# %% [markdown]
# ### Example 2.3 (Line Graphs):

# %%
# plot 2 series - team and opponent points
plt.plot(tor_2016_2017.loc[:, "Tm.Pts"], linestyle = '--',linewidth = 3, c = 'b')
plt.plot(tor_2016_2017.loc[:, "Opp.Pts"],linewidth = 5, c = 'r') 
plt.legend(['Tm.Pts','Opp.Pts'],shadow = True, loc = 0);

# %% [markdown]
# ### Problem 2
#
# Load in the Seattle Home Price Data then choose 2-3 qualitative variables and 2-3 quantitative variables to summarize using the techniques explained above.

# %%
# Write your code here

# %% [markdown]
# ### ANSWERS

# %% [markdown]
# ### Problem 1:
#
# Give an example of each type of categorical data above (other than the examples that are mentioned in the definition)

# %% [markdown]
# __Nominal Variable:__ Political party (i.e. Democratic Party, Republican Party, etc.) <br>
# __Ordinal Variable:__ Socio-economic class (i.e. working class, middle class, upper-middle class, upper class) <br>
# __Interval Variable:__ Standardized Test Score (i.e. GRE, GMAT, SAT, etc.) <br>
# __Ratio Variable:__ Height, Weight, etc. (a height of zero means something significant, a weight of zero means something significant)

# %% [markdown]
# ### Problem 2
#
# Load in the Seattle Home Price Data choose 2-3 qualitative variables and 2-3 quantitative variables to summarize using the techniques explained above.

# %%
home_df = pd.read_csv("SeattleHomePrices.csv")

# %%
home_df.head(5)
# Out:
#      SALE TYPE  SOLD DATE              PROPERTY TYPE             ADDRESS  \
# 0  MLS Listing        NaN                Condo/Co-op       510 Lee St #7
# 1  MLS Listing        NaN  Single Family Residential      352 NE 53rd St
# 2  MLS Listing        NaN  Single Family Residential   11025 21st Ave SW
# 3  MLS Listing        NaN  Single Family Residential    6846 24th Ave NE
# 4  MLS Listing        NaN                Condo/Co-op  401 9th Ave N #618
#
#       CITY STATE    ZIP   PRICE  BEDS  BATHS  ...  STATUS  \
# 0  Seattle    WA  98109  459000     2   1.00  ...  Active
# 1  Seattle    WA  98105  648000     3   1.75  ...  Active
# 2  Seattle    WA  98146  440000     3   1.75  ...  Active
# 3  Seattle    WA  98115  715000     3   1.00  ...  Active
# 4  Seattle    WA  98109  749900     1   1.50  ...  Active
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0    February-3-2018 11:00 AM  February-3-2018 01:00 PM
# 1    February-1-2018 05:00 PM  February-1-2018 07:00 PM
# 2    February-3-2018 02:00 PM  February-3-2018 04:00 PM
# 3    January-31-2018 11:00 AM  January-31-2018 01:00 PM
# 4                         NaN                       NaN
#
#    URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0  http://www.redfin.com/WA/Seattle/510-Lee-St-98...
# 1  http://www.redfin.com/WA/Seattle/352-NE-53rd-S...
# 2  http://www.redfin.com/WA/Seattle/11025-21st-Av...
# 3  http://www.redfin.com/WA/Seattle/6846-24th-Ave...
# 4  http://www.redfin.com/WA/Seattle/401-9th-Ave-N...
#
#    SOURCE     MLS#  FAVORITE INTERESTED   LATITUDE   LONGITUDE
# 0   NWMLS  1237585         N          Y  47.631632 -122.347049
# 1   NWMLS  1239016         N          Y  47.667321 -122.323260
# 2   NWMLS  1238951         N          Y  47.504199 -122.360753
# 3   NWMLS  1235253         N          Y  47.679050 -122.301420
# 4   NWMLS  1238328         N          Y  47.622291 -122.339972
#
# [5 rows x 27 columns]

# %%
home_df.dtypes
# Out:
# SALE TYPE                                                                                      object
# SOLD DATE                                                                                     float64
# PROPERTY TYPE                                                                                  object
# ADDRESS                                                                                        object
# CITY                                                                                           object
# STATE                                                                                          object
# ZIP                                                                                             int64
# PRICE                                                                                           int64
# BEDS                                                                                            int64
# BATHS                                                                                         float64
# LOCATION                                                                                       object
# SQUARE FEET                                                                                   float64
# LOT SIZE                                                                                      float64
# YEAR BUILT                                                                                    float64
# DAYS ON MARKET                                                                                  int64
# $/SQUARE FEET                                                                                 float64
# HOA/MONTH                                                                                     float64
# STATUS                                                                                         object
# NEXT OPEN HOUSE START TIME                                                                     object
# NEXT OPEN HOUSE END TIME                                                                       object
# URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)     object
# SOURCE                                                                                         object
# MLS#                                                                                            int64
# FAVORITE                                                                                       object
# INTERESTED                                                                                     object
# LATITUDE                                                                                      float64
# LONGITUDE                                                                                     float64
# dtype: object

# %% [markdown]
# - Choose the qualitative variable "PROPERTY TYPE"
# - Choose the quantitative variable "PRICE"

# %% [markdown]
# ### Part 1 - Qualitative Variables:

# %%
freq_table = pd.DataFrame(home_df.loc[:, "PROPERTY TYPE"].value_counts())
freq_table.columns = ["Frequency"]
freq_table
# Out:
#                            Frequency
# Single Family Residential        185
# Condo/Co-op                       78
# Townhouse                         47
# Vacant Land                       22
# Multi-Family (5+ Unit)             7
# Multi-Family (2-4 Unit)            6
# Other                              4
# Moorage                            1

# %%
freq_table["RelativeFrequency"] = freq_table["Frequency"] / freq_table.Frequency.sum()
freq_table
# Out:
#                            Frequency  RelativeFrequency
# Single Family Residential        185           0.528571
# Condo/Co-op                       78           0.222857
# Townhouse                         47           0.134286
# Vacant Land                       22           0.062857
# Multi-Family (5+ Unit)             7           0.020000
# Multi-Family (2-4 Unit)            6           0.017143
# Other                              4           0.011429
# Moorage                            1           0.002857

# %%
plt.figure(figsize = [8,8])
plt.pie(freq_table.RelativeFrequency, labels=freq_table.index);

# %%
plt.bar(freq_table.index,freq_table.RelativeFrequency)
plt.xticks(rotation=60);

# %% [markdown]
# ### Part 2 - Quantitative Variables:

# %%
plt.hist(home_df.loc[:, "PRICE"])
# Out:
# (array([258.,  66.,  17.,   2.,   1.,   3.,   1.,   1.,   0.,   1.]),
#  array([   75000.,  1067500.,  2060000.,  3052500.,  4045000.,  5037500.,
#          6030000.,  7022500.,  8015000.,  9007500., 10000000.]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(home_df.index, home_df.loc[:, "PRICE"])

# %%
x = home_df.index
y1 = home_df.loc[:, "PRICE"]
y2 = home_df.loc[:, "SQUARE FEET"]

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(x, y1, 'g-')
ax2.plot(x, y2, 'b-')

ax1.set_xlabel('House Index')
ax1.set_ylabel('Price', color='g')
ax2.set_ylabel('Square Feet', color='b')
# Out:
# Text(0, 0.5, 'Square Feet')

# %%
while(x>18)
